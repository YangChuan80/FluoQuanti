# %% [markdown]
# #Image Analysis

# %% [markdown]
# **Module Import**
# - PIL (Python Image Library)
# - Numpy
# - Matplotlib

# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 9E01-06D9
#
#  Directory of D:\ChuanDocuments\Documents\PySource\MMP9
#
# 10/10/2016  10:41 PM    <DIR>          .
# 10/10/2016  10:41 PM    <DIR>          ..
# 10/10/2016  09:08 PM    <DIR>          .ipynb_checkpoints
# 10/10/2016  10:41 PM         2,174,940 DensityDistinguisher.ipynb
# 10/10/2016  09:30 PM         3,145,784 HG-CTRL copy.bmp
# 10/10/2016  09:29 PM         3,145,784 HG-TB copy.bmp
# 10/10/2016  10:41 PM           797,066 image.png
# 10/10/2016  09:29 PM         3,145,784 LG-CTRL copy.bmp
# 10/10/2016  09:29 PM         3,145,784 LG-TB copy.bmp
#                6 File(s)     15,555,142 bytes
#                3 Dir(s)  141,516,460,032 bytes free

# %% [markdown]
# **Load Image Files**

# %%
img = Image.open('LG-CTRL copy.bmp')
img
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=1024x1024 at 0xFF87BA8>

# %% [markdown]
# **Helper Functions**
#
# **1. Function: Image Data Extraction**
# - matrix: RGB tuples according to the coordinates
# - integrated density: sum of green channel values
# - points: list of green channel values

# %%
def extractData(image):
    x = image.size[0]
    y = image.size[1]
    
    matrix = []
    points = []
    integrated_density = 0

    for i in range(x):
        matrix.append([])
        for j in range(y):
            matrix[i].append(image.getpixel((j,i)))
            integrated_density += image.getpixel((i,j))[1]
            points.append(image.getpixel((i,j))[1])
    return matrix, integrated_density, points

# %% [markdown]
# **2. Function: Histogram**

# %%
def creatHistogram(points_list):
    max_value = max(points_list)
    histo = [0] * (max_value + 1)
    for point in points_list:
        histo[point] +=1        
    return histo

# %% [markdown]
# **Execution**
#
# **Analysing Images**

# %%
matrix, integrated_density, points= extractData(img)

# %% [markdown]
# **Histogram Ploting**

# %%
def histoPlot(points):
    h = creatHistogram(points)
    plt.bar(range(len(h)), h, color = 'green')

# %%
histoPlot(points)

# %%
def distinguish(matrix):    
    matrix_distinguished = matrix[:]
    for i in range(1024):
        for j in range(1024):
            dark_index = 0
            if matrix[i][j][1]<35:
                if i>3 and i<1024-3 and j>3 and j<1024-3:
                    around = [matrix[x][y] for x in range(i-3, i+4) for y in range(j-3, j+4)]
                    around.remove(matrix[i][j])
                    for a in around:
                        if a[1]<30:
                            dark_index +=1
                    if dark_index >35:
                        matrix_distinguished[i][j] = (255,0,0)
                else:
                    matrix_distinguished[i][j] = (255,0,0)
    return matrix_distinguished

# %%
matrix_d = distinguish(matrix)

# %%
def imageReconstruct(matrix):
    df = np.array(matrix, dtype=np.uint8)
    img = Image.fromarray(df, 'RGB')
    img.save('image.png')
    return img

# %%
img = imageReconstruct(matrix_d)
img
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0xF396278>

# %%
def calculateDensity(matrix, matrix_d):
    interested_integrated_density = 0
    background_integrated_density = 0
    interested_area = 0
    background_area = 0
    for i in range(1024):
        for j in range(1024):
            if matrix_d[i][j][0] != 255:
                interested_integrated_density += matrix[i][j][1]
                interested_area += 1
            else:
                background_integrated_density += matrix[i][j][1]
                background_area +=1
    interested_mean = interested_integrated_density / interested_area
    background_mean = background_integrated_density / background_area
    return interested_mean - background_mean

# %%
density = calculateDensity(matrix, matrix_d)
density
# Out:
# 35.28673421591105
